# %%
from featurizations.timescales.conformational.msmrunner import MSMRunner

# %%
path = "/home/jnorth/Nextcloud/extracurriculars/publishing/research/hsu/experiments/csa_mdsim_2020_08_20_12_37_30/JLN_1_15/Acetone_1_490_SPC_res"
topology = path+"/md_0_1_490.gro"
trajectory = path+"/md_0_1_490.xtc"

MSMRunner(topology, trajectory)
# Out:
# /home/jnorth/miniconda3/envs/mdanalysis/lib/python3.8/site-packages/numpy/core/fromnumeric.py:87: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# <ipython-input-2-1bc536d50bed> in <module>
#       3 trajectory = path+"/md_0_1_490.xtc"
#       4
# ----> 5 MSMRunner(topology, trajectory)
#
# ~/Documents/GitHub/dynafeature/source/featurizations/timescales/conformational/msmrunner.py in __init__(self, top, trj, dims)
#     340         self.VAMP2dims = [i + 1 for i in range(10)]
#     341         self.VAMP2dims = [1]
# --> 342         self.figVAMP2()
# ...
